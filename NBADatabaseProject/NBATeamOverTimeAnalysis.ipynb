# %% [markdown]
# # Purpose
#
# I want to look at the history of all teams (including the ones that went defunct fairly quickly) to see if any trends can be found and correlate them with players and/or coaches. For example, the Golden State Warriors fromd around 2015 until recently had a reputation of relying on the three point shot, so I would try to find the point where they started to rely on that shot, and see if that era correlated with a coach's tenure or a player's signing or drafting.
#
# The goal is to try to get all of the seasons for a team categorized in some way. This could be done by

# %%
import sqlite3 as sql
import pandas as pd
import numpy as np
import seaborn as sns

# %%
con = sql.connect("nba.sqlite")
cur = con.cursor()
